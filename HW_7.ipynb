# %% [markdown]
# Обучить нейронную сеть для распознавания действий человека по видео на датасете KTH
# Библиотеки: [Python, Tensorflow]
# Libs

# %%
import os
import glob
import random
import numpy as np
import matplotlib.pyplot as plt
import cv2
import tensorflow_datasets as tfds
import tensorflow as tf
from tensorflow.keras import layers

# %%
# !wget http://www.nada.kth.se/cvap/actions/walking.zip
# !wget http://www.nada.kth.se/cvap/actions/jogging.zip
# !wget http://www.nada.kth.se/cvap/actions/running.zip
# !wget http://www.nada.kth.se/cvap/actions/boxing.zip
# !wget http://www.nada.kth.se/cvap/actions/handwaving.zip
# !wget http://www.nada.kth.se/cvap/actions/handclapping.zip 

# !unzip walking.zip -d walking > /dev/null
# !unzip jogging.zip -d jogging > /dev/null
# !unzip running.zip -d running > /dev/null
# !unzip boxing.zip -d boxing > /dev/null
# !unzip handwaving.zip -d handwaving > /dev/null
# !unzip handclapping.zip -d handclapping > /dev/null
# Out:
# --2021-09-24 05:54:53--  http://www.nada.kth.se/cvap/actions/walking.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/walking.zip [following]
# --2021-09-24 05:54:54--  https://www.csc.kth.se/cvap/actions/walking.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 242442411 (231M) [application/zip]
# Saving to: ‘walking.zip’
#
# walking.zip         100%[===================>] 231.21M   772KB/s    in 4m 52s
#
# 2021-09-24 05:59:47 (811 KB/s) - ‘walking.zip’ saved [242442411/242442411]
#
# --2021-09-24 05:59:47--  http://www.nada.kth.se/cvap/actions/jogging.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/jogging.zip [following]
# --2021-09-24 05:59:48--  https://www.csc.kth.se/cvap/actions/jogging.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 168961290 (161M) [application/zip]
# Saving to: ‘jogging.zip’
#
# jogging.zip         100%[===================>] 161.13M   835KB/s    in 3m 23s
#
# 2021-09-24 06:03:12 (812 KB/s) - ‘jogging.zip’ saved [168961290/168961290]
#
# --2021-09-24 06:03:12--  http://www.nada.kth.se/cvap/actions/running.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/running.zip [following]
# --2021-09-24 06:03:13--  https://www.csc.kth.se/cvap/actions/running.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149756643 (143M) [application/zip]
# Saving to: ‘running.zip’
#
# running.zip         100%[===================>] 142.82M   838KB/s    in 3m 0s
#
# 2021-09-24 06:06:14 (812 KB/s) - ‘running.zip’ saved [149756643/149756643]
#
# --2021-09-24 06:06:14--  http://www.nada.kth.se/cvap/actions/boxing.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/boxing.zip [following]
# --2021-09-24 06:06:15--  https://www.csc.kth.se/cvap/actions/boxing.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 194498294 (185M) [application/zip]
# Saving to: ‘boxing.zip’
#
# boxing.zip          100%[===================>] 185.49M   836KB/s    in 3m 54s
#
# 2021-09-24 06:10:10 (811 KB/s) - ‘boxing.zip’ saved [194498294/194498294]
#
# --2021-09-24 06:10:10--  http://www.nada.kth.se/cvap/actions/handwaving.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/handwaving.zip [following]
# --2021-09-24 06:10:11--  https://www.csc.kth.se/cvap/actions/handwaving.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 218981954 (209M) [application/zip]
# Saving to: ‘handwaving.zip’
#
# handwaving.zip      100%[===================>] 208.84M   815KB/s    in 4m 23s
#
# 2021-09-24 06:14:35 (813 KB/s) - ‘handwaving.zip’ saved [218981954/218981954]
#
# --2021-09-24 06:14:35--  http://www.nada.kth.se/cvap/actions/handclapping.zip
# Resolving www.nada.kth.se (www.nada.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.nada.kth.se (www.nada.kth.se)|130.237.28.41|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.csc.kth.se/cvap/actions/handclapping.zip [following]
# --2021-09-24 06:14:36--  https://www.csc.kth.se/cvap/actions/handclapping.zip
# Resolving www.csc.kth.se (www.csc.kth.se)... 130.237.28.41, 2001:6b0:1:11c2::82ed:1c29
# Connecting to www.csc.kth.se (www.csc.kth.se)|130.237.28.41|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 176901831 (169M) [application/zip]
# Saving to: ‘handclapping.zip’
#
# handclapping.zip    100%[===================>] 168.71M   823KB/s    in 3m 33s
#
# 2021-09-24 06:18:10 (812 KB/s) - ‘handclapping.zip’ saved [176901831/176901831]

# %%
# Prep dataset
classes = ['walking', 'jogging', 'running', 'boxing', 'handwaving', 'handclapping']
DATA_ROOT = './'

# %%
dataset = []
for cls in classes:
    videos = os.path.join(DATA_ROOT, cls, '*.avi')
    videos = glob.glob(videos)
    for v in videos:
        cls_idx = classes.index(cls)
        dataset.append([v, cls_idx])
        
print(len(dataset))
print(dataset[:5])
# Out:
# 599
# [['./walking/person06_walking_d2_uncomp.avi', 0], ['./walking/person02_walking_d2_uncomp.avi', 0], ['./walking/person11_walking_d2_uncomp.avi', 0], ['./walking/person07_walking_d2_uncomp.avi', 0], ['./walking/person19_walking_d3_uncomp.avi', 0]]

# %%
def get_video_arr(path):
    """
    get video array
    """
    videodata = cv2.VideoCapture(path)
    
    video_array = []
    while True:
        frame = videodata.read()
        if frame[0]:
            video_array.append(frame[1])
        else: 
            return np.array(video_array)

# %%
#shuffle and split videos: 9/1

random.shuffle(dataset)
count = int(len(dataset) * 0.9)
train, test = dataset[:count], dataset[count:]
len(train), len(test)
# Out:
# (539, 60)

# %%
videodata = get_video_arr(dataset[0][0])
videodata = videodata.astype(np.float32) / 255.
print('videodata shape:', videodata.shape)
plt.imshow(videodata[25])
# Out:
# videodata shape: (500, 120, 160, 3)

# %%
# Vied motion
motion = np.mean(videodata[1:] - videodata[:-1], axis=3, keepdims=True)
print('motion shape:', motion.shape)
plt.imshow(motion[25, ..., 0], cmap='gray')
# Out:
# motion shape: (499, 120, 160, 1)

# %% [markdown]
# CNN model

# %%
model = tf.keras.Sequential([
    layers.Conv3D(32, (5, 5, 5), (1, 2, 2), padding='same', activation='relu'),
    layers.MaxPool3D((1, 2, 2), padding='same'),
    layers.Conv3D(64, (5, 5, 5), (1, 2, 2), padding='same', activation='relu'),
    layers.MaxPool3D((1, 2, 2), padding='same'),
    layers.Conv3D(64, (3, 3, 3), (1, 2, 2), padding='same', activation='relu'),
    layers.MaxPool3D((1, 2, 2), padding='same'),
    layers.Conv3D(64, (3, 3, 3), (1, 1, 1), padding='same', activation=None),
    
    layers.GlobalAveragePooling3D(),
    layers.Dense(64, activation='relu'),
    layers.Dense(6, activation=None),
])

# %%
LEARNING_RATE = 0.001
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), 
    optimizer=tf.keras.optimizers.Adam(LEARNING_RATE)
)
writer = tf.summary.create_file_writer('logs/exp1')

# %%
# Training
def prep_to_model(path, lbl):

    # preperation data to model
    videodata = get_video_arr(path)
    videodata = videodata.astype(np.float32) / 255.

    motion = np.mean(videodata[1:] - videodata[:-1], axis=3, keepdims=True)

    x = motion[None, ...]
    y = np.array(lbl)[None, ...]
    
    return x, y

# %%
# %%time
EPOCHS = 10
train_loss = []
test_loss = []

for ep in range(EPOCHS):
    for i, (path, lbl) in enumerate(train):
        x, y = prep_to_model(path, lbl)
        train_loss_value = model.train_on_batch(x, y)
        
        if i % 32 == 0:
            path, lbl = random.choice(test)
            
            x, y = prep_to_model(path, lbl)
            test_loss_value = model.test_on_batch(x, y)
            
            train_loss.append(train_loss_value)
            test_loss.append(test_loss_value)
            
            print(f'[{ep}/{EPOCHS}][{i}/{len(train)}] Train loss = {train_loss_value} | Test loss = {test_loss_value}')
# Out:
# [0/10][0/539] Train loss = 1.7917066812515259 | Test loss = 1.8526371717453003
# [0/10][32/539] Train loss = 1.7419110536575317 | Test loss = 1.7460530996322632
# [0/10][64/539] Train loss = 1.8499423265457153 | Test loss = 1.7671034336090088
# [0/10][96/539] Train loss = 1.7635605335235596 | Test loss = 1.7357832193374634
# [0/10][128/539] Train loss = 1.0182856321334839 | Test loss = 3.172637939453125
# [0/10][160/539] Train loss = 1.8143141269683838 | Test loss = 1.7916219234466553
# [0/10][192/539] Train loss = 1.5500844717025757 | Test loss = 1.4803098440170288
# [0/10][224/539] Train loss = 0.926906406879425 | Test loss = 0.9268826842308044
# [0/10][256/539] Train loss = 1.5698511600494385 | Test loss = 1.3438847064971924
# [0/10][288/539] Train loss = 1.28401517868042 | Test loss = 1.3613611459732056
# [0/10][320/539] Train loss = 3.9335250854492188 | Test loss = 1.1230894327163696
# [0/10][352/539] Train loss = 2.1962060928344727 | Test loss = 3.677799940109253
# [0/10][384/539] Train loss = 2.9791970252990723 | Test loss = 1.241079568862915
# [0/10][416/539] Train loss = 1.2447302341461182 | Test loss = 0.6829528212547302
# [0/10][448/539] Train loss = 0.11811157315969467 | Test loss = 1.3965555429458618
# [0/10][480/539] Train loss = 0.539178729057312 | Test loss = 1.735799789428711
# [0/10][512/539] Train loss = 1.0104138851165771 | Test loss = 0.44025516510009766
# [1/10][0/539] Train loss = 0.16616781055927277 | Test loss = 1.222118854522705
# [1/10][32/539] Train loss = 0.031777191907167435 | Test loss = 0.4923780560493469
# [1/10][64/539] Train loss = 1.737025260925293 | Test loss = 0.9582786560058594
# [1/10][96/539] Train loss = 1.6285617351531982 | Test loss = 0.00030501006403937936
# [1/10][128/539] Train loss = 1.1920922133867862e-06 | Test loss = 0.13465003669261932
# [1/10][160/539] Train loss = 1.3124077320098877 | Test loss = 1.174173355102539
# [1/10][192/539] Train loss = 0.6246753334999084 | Test loss = 0.29775190353393555
# [1/10][224/539] Train loss = 0.464354932308197 | Test loss = 0.03746446594595909
# [1/10][256/539] Train loss = 1.2944989204406738 | Test loss = 3.785224199295044
# [1/10][288/539] Train loss = 0.665629506111145 | Test loss = 0.45418375730514526
# [1/10][320/539] Train loss = 7.730691909790039 | Test loss = 0.4615952968597412
# [1/10][352/539] Train loss = 1.9495539665222168 | Test loss = 1.750564455986023
# [8/10][256/539] Train loss = 0.01089139562100172 | Test loss = 0.050056342035532
# [8/10][288/539] Train loss = 0.006046455819159746 | Test loss = 5.006777428206988e-06
# [8/10][320/539] Train loss = 5.574601650238037 | Test loss = 0.0
# [8/10][352/539] Train loss = 1.8834065198898315 | Test loss = 0.0002431573811918497
# [8/10][384/539] Train loss = 0.5712669491767883 | Test loss = 6.318072337307967e-06
# [8/10][416/539] Train loss = 0.012388422153890133 | Test loss = 0.0006800960982218385
# [8/10][448/539] Train loss = 4.6491513785440475e-06 | Test loss = 0.0013955625472590327
# [8/10][480/539] Train loss = 8.344646857949556e-07 | Test loss = 0.0024034681264311075
# [8/10][512/539] Train loss = 0.0007979070069268346 | Test loss = 0.1524459719657898
# [9/10][0/539] Train loss = 0.0 | Test loss = 0.18492451310157776
# [9/10][32/539] Train loss = 1.311301275563892e-06 | Test loss = 0.3346777856349945
# [9/10][64/539] Train loss = 0.49069246649742126 | Test loss = 1.1086402082582936e-05
# [9/10][96/539] Train loss = 0.00024041623692028224 | Test loss = 0.06690984964370728
# [9/10][128/539] Train loss = 0.0 | Test loss = 0.0
# [9/10][160/539] Train loss = 5.018585216021165e-05 | Test loss = 0.14811336994171143
# [9/10][192/539] Train loss = 0.00031680811662226915 | Test loss = 0.0
# [9/10][224/539] Train loss = 5.245195097813848e-06 | Test loss = 0.03460892289876938
# [9/10][256/539] Train loss = 0.0020095170475542545 | Test loss = 0.0008998635457828641
# [9/10][288/539] Train loss = 0.0006053998949937522 | Test loss = 1.2397689715726301e-05
# [9/10][320/539] Train loss = 0.022066306322813034 | Test loss = 3.957670196541585e-05
# [9/10][352/539] Train loss = 1.6402537822723389 | Test loss = 0.005847608670592308
# [9/10][384/539] Train loss = 1.0522665977478027 | Test loss = 0.004372559953480959
# [9/10][416/539] Train loss = 0.02006588689982891 | Test loss = 0.43566879630088806
# [9/10][448/539] Train loss = 0.0016613503685221076 | Test loss = 0.0
# [9/10][480/539] Train loss = 0.0017376337200403214 | Test loss = 0.04081886634230614
# [9/10][512/539] Train loss = 0.00012432756193447858 | Test loss = 0.07087184488773346
# CPU times: user 42min 5s, sys: 1min 21s, total: 43min 26s
# Wall time: 46min 10s

# %%
plt.plot(train_loss)
plt.plot(test_loss)

# %% [markdown]
# Testing

# %%
for i in range(4):
  fpath, cls_true = random.choice(test)
  motion = prep_to_model(fpath, cls_true)[0]

  prob = model(motion)
  prob = prob[0].numpy()

  pred = np.argmax(prob)

  print(f'True: {classes[cls_true]}\n',
        f'Pred: {classes[pred]}\n', sep='')

  plt.figure(figsize=(14, 2))
  
  plt.subplot(1, 2, 1)
  videodata = get_video_arr(fpath)
  plt.imshow(videodata[25, ..., 0], cmap='gray')
  plt.axis('off')

  plt.subplot(1, 2, 2)
  motion_prob = sorted(zip(classes, prob), key=lambda mp: mp[1])
  m = np.array(motion_prob)[:, 0]
  p = np.array(motion_prob)[:, 1].astype(np.float32)
  bars = plt.barh(m, p)

  plt.show()
# Out:
# True: boxing
# Pred: boxing
# True: boxing
# Pred: boxing
# True: handclapping
# Pred: handclapping
# True: jogging
# Pred: jogging

# %% [markdown]
# Как-то так :)
